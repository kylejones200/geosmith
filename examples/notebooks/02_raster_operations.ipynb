# %% [markdown]
# ## Summary
#
# This notebook demonstrated:
# 1. ✅ Creating RasterGrid objects
# 2. ✅ Clipping rasters to polygon boundaries
# 3. ✅ Resampling rasters to new resolutions
# 4. ✅ Computing zonal statistics (mean, min, max, std)
# 5. ✅ Visualizing results with PlotSmith and matplotlib
#
# All operations follow GeoSmith's 4-layer architecture, ensuring clean separation of concerns and maintainable code.
